# %% [markdown]
# # Exercise 2.A Using built-in functions
# ## Lab 1. Working with names - parsing strings

# %%
test_name = 'John Doe'

# %%
def jellybean():
    yield "This is a jellybean counter"
    jellybean = 0
    while jellybean <= 4:
        yield f'We have {jellybean} jellybeans'
        jellybean += 1
    yield "That's enough jellybeans"

# %%
for j in jellybean():
    print(j)
# Out:
# This is a jellybean counter
# We have 0 jellybeans
# We have 1 jellybeans
# We have 2 jellybeans
# We have 3 jellybeans
# We have 4 jellybeans
# That's enough jellybeans
